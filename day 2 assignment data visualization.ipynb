# %%
#chinmayee mschinmayee0@gmail.com

# %%
import numpy as np
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from numpy.random import randn , randint , uniform , sample

# %%
df=pd.DataFrame(randn(10,4), columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  1.054934  0.206997  0.564040  0.371325
# 1 -1.081653 -1.043469 -0.852395 -0.506944
# 2 -0.334968 -0.899481  1.143916 -0.385212
# 3  0.017913 -0.173169  0.586462 -0.554984
# 4 -1.217232 -1.158220  0.574098 -0.681155
# 5 -0.727347  0.141055 -0.248336  0.325750
# 6 -1.275835 -0.419042  0.277852 -1.076555
# 7 -1.753745  1.156317 -0.327888  0.877868
# 8  0.275342  1.317673  1.548055 -0.366628
# 9 -0.135811 -1.279725 -0.280220 -1.607536

# %%
df.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.517840  -0.215106   0.298558  -0.360407
# std     0.851281   0.928321   0.734605   0.728059
# min    -1.753745  -1.279725  -0.852395  -1.607536
# 25%    -1.183337  -1.007472  -0.272249  -0.649612
# 50%    -0.531158  -0.296106   0.420946  -0.446078
# 75%    -0.020518   0.190512   0.583371   0.152655
# max     1.054934   1.317673   1.548055   0.877868

# %%
df.plot(kind='bar',figsize=(10,10))
plt.title("BAR GRAPH",color='b')
plt.show()
